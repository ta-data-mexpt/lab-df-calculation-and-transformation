# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("Orders.csv")
orders.head()

print(orders["Country"].unique())
# Out:
# ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Finland' 'Austria' 'Greece' 'Singapore' 'Lebanon'
#  'United Arab Emirates' 'Israel' 'Saudi Arabia' 'Czech Republic' 'Canada'
#  'Unspecified' 'Brazil' 'USA' 'European Community' 'Bahrain' 'Malta' 'RSA']

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here

print(orders.columns)

grouped_orders = orders.groupby("CustomerID", as_index = False).agg( "sum")

vip_percentile = grouped_orders["amount_spent"].quantile(0.95)
print(vip_percentile)

vip_customer_ids = grouped_orders[grouped_orders["amount_spent"] > float(vip_percentile)]

vip_customer_ids.head()
# Out:
# Index(['Unnamed: 0', 'InvoiceNo', 'StockCode', 'year', 'month', 'day', 'hour',
#        'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID',
#        'Country', 'amount_spent'],
#       dtype='object')
# 5840.181999999982
# C:\Users\tglhi\AppData\Local\Temp\ipykernel_8580\1024278506.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_orders = orders.groupby("CustomerID", as_index = False).agg( "sum")
#     CustomerID  Unnamed: 0  InvoiceNo     year  month   day  hour  Quantity  \
# 0        12346       61619     541431     2011      1     2    10     74215
# 10       12357    58262250   75290940   263441   1441   917  2096      2708
# 12       12359    59103884  138190725   498728   1508   783  3136      1622
# ...

# %%
vip_customers_list = []

for customerid in vip_customer_ids["CustomerID"]:
    my_customer = grouped_orders.loc[grouped_orders["CustomerID"] == customerid]
    vip_customers_list.append(my_customer)
    
vip_customers = pd.concat(vip_customers_list)

sorted_vip_customers = vip_customers.sort_values("amount_spent", ascending = False)

# THESE ARE THE VIP CUSTOMERS

sorted_vip_customers.head(30)
# Out:
#       CustomerID  Unnamed: 0   InvoiceNo      year  month    day    hour  \
# 1690       14646   544561120  1163267611   4182810  14191   6552   24488
# 4202       18102   138022684   243297801    866723   3746   1261    5587
# 3729       17450    92683919   188845149    677704   2292    842    4140
# 3009       16446      929130     1688629      6033     22     11      27
# 1880       14911  1737367680  3196374868  11416155  46220  18930   68148
# 55         12415   164201777   398543981   1439876   4254   2169    8061
# 1334       14156   336350387   780541003   2815397   8630   4284   17201
# 3772       17511   248601574   538173446   1936505   7215   2701   11320
# 2703       16029    54851121   134645942    486630   1777    748    2789
# 0          12346       61619      541431      2011      1      2      10
# 3177       16684    73386112   154941215    557024   2086   1057    3201
# 1290       14096  2234732776  2933997631  10278221  53171   8284   73542
# ...

# %%
preferred_percentile = grouped_orders["amount_spent"].quantile(0.75)
print(preferred_percentile)

preferred_customer_ids = grouped_orders[(grouped_orders["amount_spent"] > float(preferred_percentile)) & 
                                        (grouped_orders["amount_spent"] <= float(vip_percentile))]

preferred_customers_list = []

for customerid in preferred_customer_ids["CustomerID"]:
    my_customer = grouped_orders.loc[grouped_orders["CustomerID"] == customerid]
    preferred_customers_list.append(my_customer)
    
preferred_customers = pd.concat(preferred_customers_list)

sorted_preferred_customers = preferred_customers.sort_values("amount_spent", ascending = False)

# THESE ARE THE PREFERRED CUSTOMERS

sorted_preferred_customers.head(30)
# Out:
# 1661.64
#       CustomerID  Unnamed: 0  InvoiceNo     year  month   day   hour  \
# 537        13050    88073344  223872574   810364   2992  1278   4940
# 304        12720    90950303  197785584   711849   2760  1106   4153
# 2105       15218    41221248   92641005   333826   1009   302   1823
# 3904       17686    72758466  159766169   575146   1824   905   3433
# 631        13178    59276272  147365548   532883   1858   872   3321
# 3084       16553    10948254   46009406   168907    463   270   1098
# 836        13468    60617105  167242110   607269   2119  1021   3744
# 1301       14110    40826438   87272614   313716   1064   519   1731
# 1256       14049   146916305  274322831   981368   3318  1132   5580
# 3448       17049   104082504  179636687   639498   2610   901   3680
# 3928       17716    61599309  136854813   492695   1615   674   3175
# 504        13004    99121795  225341111   812421   2697  1374   4645
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %%
# Q2

non_grouped_vips_list = []

for customerid in vip_customers["CustomerID"]:
    vip_customer = orders.loc[orders["CustomerID"] == customerid]
    non_grouped_vips_list.append(vip_customer)
    
non_grouped_vips = pd.concat(non_grouped_vips_list)

country_vips = non_grouped_vips.groupby("Country").nunique()

# These are the countries with most VIP customers. First one is UK

country_vips.sort_values("CustomerID", ascending = False)
# Out:
#                  Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# Country
# United Kingdom        84185       4165       3155     2     12    6    14
# Germany                3127        127        991     2     12    6    10
# France                 3290        128        879     2     12    6    11
# Switzerland             594          9        433     1      6    5     7
# Spain                   511         22        291     2     11    6     9
# Portugal                681         20        378     2      9    6     8
# Australia               898         34        496     2     12    6     8
# EIRE                   7077        256       1929     2     12    6    13
# Japan                   205          9        136     2      8    4     6
# Finland                 294          9        258     1      5    5     6
# Belgium                  54          2         51     1      2    2     2
# ...

# %%
# Q3

non_grouped_preferred_list = []

for customerid in preferred_customers["CustomerID"]:
    preferred_customer = orders.loc[orders["CustomerID"] == customerid]
    non_grouped_preferred_list.append(preferred_customer)
    
non_grouped_preferred = pd.concat(non_grouped_preferred_list)

non_grouped_vips_preferred = pd.concat([non_grouped_vips, non_grouped_preferred])

non_grouped_vips_preferred.head()

country_vips_preferred = non_grouped_vips_preferred.groupby("Country").nunique()

# These are the countries with most VIP and Preferred customers. First one is UK

country_vips_preferred.sort_values("CustomerID", ascending = False)
# Out:
#                  Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# Country
# United Kingdom       221635       9952       3491     2     12    6    15
# Germany                7349        350       1518     2     12    6    10
# France                 6301        264       1262     2     12    6    12
# Belgium                1557         67        688     2     12    6    11
# Switzerland            1370         30        779     2     11    6    11
# Spain                  1569         47        805     2     12    6    10
# Portugal               1093         38        566     2     12    6     9
# Norway                 1028         33        573     2      9    6     9
# Italy                   507         27        310     1     12    6     8
# Finland                 504         31        365     2     10    6    12
# Japan                   272         14        181     2      8    6     7
# ...
