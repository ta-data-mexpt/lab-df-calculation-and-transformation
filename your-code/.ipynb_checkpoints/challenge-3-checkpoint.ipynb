# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("../../lab-subsetting-and-descriptive-stats/your-code/Orders.csv")
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010   12.0  3.0   8.0
# 1           1     536365     71053  2010   12.0  3.0   8.0
# 2           2     536365    84406B  2010   12.0  3.0   8.0
# 3           3     536365    84029G  2010   12.0  3.0   8.0
# 4           4     536365    84029E  2010   12.0  3.0   8.0
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder       6.0  2010-12-01 08:26:00
# 1                  white metal lantern       6.0  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger       8.0  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle       6.0  2010-12-01 08:26:00
# 4       red woolly hottie white heart.       6.0  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55     17850.0  United Kingdom         15.30
# 1       3.39     17850.0  United Kingdom         20.34
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
orders2 = orders[['CustomerID','amount_spent']].groupby('CustomerID').agg({'amount_spent': 'sum'}).sort_values('amount_spent', ascending=False)
orders2
# Out:
#             amount_spent
# CustomerID
# 15061.0          9407.34
# 13777.0          6585.16
# 17850.0          5391.21
# 16210.0          4738.54
# 16029.0          4271.52
# ...                  ...
# 14865.0            37.20
# 14576.0            35.40
# 17026.0            33.15
# 15356.0            20.65
# 15823.0            15.00
#
# [356 rows x 1 columns]

# %%
orders2['5_percent_quantiles']=pd.qcut(orders2['amount_spent'],20,labels=False)
orders2
# Out:
#             amount_spent  5_percent_quantiles
# CustomerID
# 15061.0          9407.34                   19
# 13777.0          6585.16                   19
# 17850.0          5391.21                   19
# 16210.0          4738.54                   19
# 16029.0          4271.52                   19
# ...                  ...                  ...
# 14865.0            37.20                    0
# 14576.0            35.40                    0
# 17026.0            33.15                    0
# 15356.0            20.65                    0
# 15823.0            15.00                    0
#
# [356 rows x 2 columns]

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %%
# your code here
#VIP: top 5%
#Preferred: top 75-95%
orders2['VIP']= np.where(orders2['5_percent_quantiles']>=19,1,0)
orders2
# Out:
#             amount_spent  5_percent_quantiles  VIP
# CustomerID
# 15061.0          9407.34                   19    1
# 13777.0          6585.16                   19    1
# 17850.0          5391.21                   19    1
# 16210.0          4738.54                   19    1
# 16029.0          4271.52                   19    1
# ...                  ...                  ...  ...
# 14865.0            37.20                    0    0
# 14576.0            35.40                    0    0
# 17026.0            33.15                    0    0
# 15356.0            20.65                    0    0
# 15823.0            15.00                    0    0
#
# [356 rows x 3 columns]

# %%
orders2['Preferred']= np.where(((orders2['5_percent_quantiles']>=15) & (orders2['5_percent_quantiles']<19)),1,0)

# %%
orders2
# Out:
#             amount_spent  5_percent_quantiles  VIP  Preferred
# CustomerID
# 15061.0          9407.34                   19    1          0
# 13777.0          6585.16                   19    1          0
# 17850.0          5391.21                   19    1          0
# 16210.0          4738.54                   19    1          0
# 16029.0          4271.52                   19    1          0
# ...                  ...                  ...  ...        ...
# 14865.0            37.20                    0    0          0
# 14576.0            35.40                    0    0          0
# 17026.0            33.15                    0    0          0
# 15356.0            20.65                    0    0          0
# 15823.0            15.00                    0    0          0
#
# [356 rows x 4 columns]

# %%
result = pd.merge(orders, orders2, how='left', on = 'CustomerID')

# %%
result.head(2)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010   12.0  3.0   8.0
# 1           1     536365     71053  2010   12.0  3.0   8.0
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder       6.0  2010-12-01 08:26:00
# 1                 white metal lantern       6.0  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent_x  amount_spent_y  \
# 0       2.55     17850.0  United Kingdom           15.30         5391.21
# 1       3.39     17850.0  United Kingdom           20.34         5391.21
#
#    5_percent_quantiles  VIP  Preferred
# 0                 19.0  1.0        0.0
# 1                 19.0  1.0        0.0

# %%
result.groupby(by='Country').sum('VIP').sort_values('VIP', ascending=False)
# Out:
#                 Unnamed: 0   InvoiceNo      year     month      day      hour  \
# Country
# United Kingdom    53735123  4561113687  17074950  101940.0  36601.0  108356.0
# EIRE                973215    70885505    265320    1584.0    473.0    1790.0
# Norway               92856    39166836    146730     876.0    219.0     949.0
# Germany            1489716    96677211    361800    2160.0   1041.0    2479.0
# Australia             2849     7509446     28140     168.0     42.0     140.0
# Belgium              87414     6444312     24120     144.0     60.0     192.0
# France              643277    56912043    213060    1272.0    616.0    1124.0
# Italy               173412    12888528     48240     288.0    120.0     360.0
# Japan               156648     8595488     32160     192.0    112.0     240.0
# Lithuania           272085    18260803     68340     408.0    238.0     408.0
# Netherlands            771     1072806      4020      24.0      6.0      22.0
# ...
